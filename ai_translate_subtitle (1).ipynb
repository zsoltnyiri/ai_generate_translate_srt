# %%
'''https://huggingface.co/openai/whisper-large-v3'''

# %%
pip install --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset

device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe("tanuljunk_kutyaul.m4a", generate_kwargs={"language": "hungarian", "task": "translate"}, return_timestamps=True)
print(result["text"])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#  Hello everyone, good afternoon! This is a very interesting topic. Why do we have to talk about the dog? Why do we talk about the dog? Why don't we talk about the dog? Well, we say that we have to talk about the dog. We don't hold this presentation by accident, we don't at this moment, we are in the middle of a huge change, a dog paradigm shift. I would like to prove this right away. I would like to start with a question. put your hand on the dog's hand who chose a specific dog for you. So when he went to the dog house, he went to the dog house, then he looked at the little dog with that eye, that he would be a racing dog from Egiliti, or a lion dog, or he would hunt with you. Put your hand on the hand who chose your dog like this. Three, four, five. Thank you. And now I would like to ask you to raise your hand if you chose your dog as a family member. You went to the dog for a walk. Okay, and you raised your hand, by the way, who is the first. If I had raised this question a hundred years ago, I would have got exactly the same ratio. Exactly the same, just reversed. Ladies and gentlemen, this is the dog paradigm shift. And in this soul-teaching, we just look a little bit to see what I think. The dog is here with us today, in the family, in the human family. Specifically, I have a Caucasian shepherd dog, and although we have a nice big house, but it sleeps in the living room and the bedroom. This is how we live with the dog today. However, this was not exactly the case in the past few thousand years. But all in all, if I look at the relationship between man and dog, I will notice a very interesting phenomenon. Some say that it is 150,000 years, some say that it is only 50,000 years. It depends on what you say that it is only for 150,000 years, others say that it is only for 50,000 years. It depends on what you say about it. There are completely different definitions of science. I want to start from 150,000 years. We live with the dog for 150,000 years. The dog spent 145-147 thousand years in the sunbed and the bedroom. And only in the last 3-4 thousand years did we put him out. He was brought out to the yard, to the gate. Before that, he lived with us in the sunbed and the bedroom. That was a very big change when, at the beginning of our written history, the dog practically distanced itself from man, but to predict that, the human and the dog would be again in a very close proximity, would be again in the human family, in the human bedroom and in the bedroom. This can be argued, but it is too much. This has happened, this is now, this is how we live with the dog today, and that's exactly why what is happening now, this is how we live with the dog today. And that's exactly why we have to talk about who is the miracle, what is the miracle of this dog. Because, please, with the fact that the dog has moved into the human family, we have taken a lot of responsibility with it. And actually, I would like to talk about this responsibility now in the time ahead of us. Well, let's get into it and see what I think. What are the actual needs of the dog, how does the dog work? The mirror method basically says that the dog is doing fine. We don't really have to teach the dog, but he's waiting for his owner to arrive. And that's why you and the man and dog is placed on three levels. These three levels are teaching, relationship management and lifestyle. Today I'm going to talk about this. Typically, the most common is relationship management, but to get a wider picture of the dog, I would like to look a little bit out of the teaching and the lifestyle. Let's start with the lifestyle. What does it mean to be a lifestyle? It's a popular word, we really like to use it today. Well, the situation is that when the dog was not in the human family yet, but we used the dog for something, then we took the dog's energy. If we go back, so we go back to the pre-human coexistence period, then we see that he was able to give his energy in an exciting way a ...

# %%
result["chunks"]
# Out:
# [{'timestamp': (0.0, 3.0), 'text': ' Hello everyone, good afternoon!'},
#  {'timestamp': (3.0, 6.0), 'text': ' This is a very interesting topic.'},
#  {'timestamp': (6.0, 10.0), 'text': ' Why do we have to talk about the dog?'},
#  {'timestamp': (10.0, 13.0),
#   'text': " Why do we talk about the dog? Why don't we talk about the dog?"},
#  {'timestamp': (13.0, 16.0),
#   'text': ' Well, we say that we have to talk about the dog.'},
#  {'timestamp': (16.0, 35.0),
#   'text': " We don't hold this presentation by accident, we don't at this moment, we are in the middle of a huge change, a dog paradigm shift."},
#  {'timestamp': (35.0, 37.0),
#   'text': ' I would like to prove this right away.'},
#  {'timestamp': (37.0, 46.4),
#   'text': " I would like to start with a question. put your hand on the dog's hand who chose a specific dog for you."},
#  {'timestamp': (46.4, 49.2),
#   'text': ' So when he went to the dog house, he went to the dog house,'},
#  {'timestamp': (49.2, 54.5),
#   'text': ' then he looked at the little dog with that eye,'},
#  {'timestamp': (54.5, 60.3),
#   'text': ' that he would be a racing dog from Egiliti, or a lion dog, or he would hunt with you.'},
#  {'timestamp': (60.3, 65.0),
#   'text': ' Put your hand on the hand who chose your dog like this.'},
#  {'timestamp': (65.0, 68.0), 'text': ' Three, four, five. Thank you.'},
#  {'timestamp': (68.0, 77.0),
#   'text': ' And now I would like to ask you to raise your hand if you chose your dog as a family member.'},
#  {'timestamp': (77.0, 82.0), 'text': ' You went to the dog for a walk.'},
#  {'timestamp': (82.0, 86.0),
#   'text': ' Okay, and you raised your hand, by the way, who is the first.'},
#  {'timestamp': (86.0, 95.0),
#   'text': ' If I had raised this question a hundred years ago, I would have got exactly the same ratio.'},
#  {'timestamp': (95.0, 98.0), 'text': ' Exactly the same, just reversed.'},
#  {'timestamp': (98.0, 102.0),
#   'text': ' Ladies and gentlemen, this is the dog paradigm shift.'},
#  {'timestamp': (102.0, 107.0),
#   'text': ' And in this soul-teaching, we just look a little bit to see what I think.'},
#  {'timestamp': (107.0, 114.0),
#   'text': ' The dog is here with us today, in the family, in the human family.'},
#  {'timestamp': (114.0, 123.0),
#   'text': ' Specifically, I have a Caucasian shepherd dog, and although we have a nice big house, but it sleeps in the living room and the bedroom.'},
#  {'timestamp': (123.0, 125.0),
#   'text': ' This is how we live with the dog today.'},
#  {'timestamp': (127.0, 132.0),
#   'text': ' However, this was not exactly the case in the past few thousand years.'},
#  {'timestamp': (132.0, 136.0),
#   'text': ' But all in all, if I look at the relationship between man and dog,'},
#  {'timestamp': (136.0, 141.0),
#   'text': ' I will notice a very interesting phenomenon.'},
#  {'timestamp': (142.0, 144.0), 'text': ' Some say that it is 150,000 years,'},
#  {'timestamp': (144.0, 146.0),
#   'text': ' some say that it is only 50,000 years. It depends on what you say that it is only for 150,000 years, others say that it is only for 50,000 years.'},
#  {'timestamp': (146.0, 149.0),
#   'text': ' It depends on what you say about it.'},
#  {'timestamp': (149.0, 152.0),
#   'text': ' There are completely different definitions of science.'},
#  {'timestamp': (152.0, 155.0), 'text': ' I want to start from 150,000 years.'},
#  {'timestamp': (155.0, 170.0),
#   'text': ' We live with the dog for 150,000 years. The dog spent 145-147 thousand years in the sunbed and the bedroom.'},
#  {'timestamp': (170.0, 174.0),
#   'text': ' And only in the last 3-4 thousand years did we put him out.'},
#  {'timestamp': (174.0, 176.0),
#   'text': ' He was brought out to the yard, to the gate.'},
#  {'timestamp': (176.0, 181.0),
#   'text': ' Before that, he lived with us in the sunbed and the bedroom.'},
#  {'timestamp': (181.0, 208.7),
#   'text': ' That was a very big change when, at the beginning of our written history, the dog practically distanced itself from man, but to predict that, the human and the dog would be again in a very close proximity,'},
#  {'timestamp': (208.7, 214.8),
#   'text': ' would be again in the human family, in the human bedroom and in the bedroom.'},
#  {'timestamp': (216.0, 220.7),
#   'text': ' This can be argued, but it is too much.'},
#  {'timestamp': (220.7, 223.7),
#   'text': ' This has happened, this is now, this is how we live with the dog today,'},
#  {'timestamp': (223.7, 231.0),
#   'text': " and that's exactly why what is happening now, this is how we live with the dog today. And that's exactly why we have to talk about who is the miracle, what is the miracle of this dog."},
#  {'timestamp': (231.0, 238.0),
#   'text': ' Because, please, with the fact that the dog has moved into the human family, we have taken a lot of responsibility with it.'},
#  {'timestamp': (238.0, 243.0),
#   'text': ' And actually, I would like to talk about this responsibility now in the time ahead of us.'},
#  {'timestamp': (243.0, 246.6),
#   'text': " Well, let's get into it and see what I think."},
#  {'timestamp': (249.64, 252.56),
#   'text': ' What are the actual needs of the dog, how does the dog work?'},
#  {'timestamp': (253.12, 258.0),
#   'text': ' The mirror method basically says that the dog is doing fine.'},
#  {'timestamp': (259.12, 264.36),
#   'text': " We don't really have to teach the dog, but he's waiting for his owner to arrive."},
#  {'timestamp': (269.0, 274.0),
#   'text': " And that's why you and the man and dog is placed on three levels. These three levels are teaching, relationship management and lifestyle."},
#  {'timestamp': (274.0, 277.0), 'text': " Today I'm going to talk about this."},
#  {'timestamp': (277.0, 282.0),
#   'text': ' Typically, the most common is relationship management,'},
#  {'timestamp': (282.0, 290.6),
#   'text': ' but to get a wider picture of the dog, I would like to look a little bit out of the teaching and the lifestyle.'},
#  {'timestamp': (290.6, 295.6),
#   'text': " Let's start with the lifestyle. What does it mean to be a lifestyle? It's a popular word, we really like to use it today."},
#  {'timestamp': (295.6, 302.6),
#   'text': ' Well, the situation is that when the dog was not in the human family yet, but we used the dog for something,'},
#  {'timestamp': (302.6, 308.66),
#   'text': " then we took the dog's energy. If we go back, so we go back to the pre-human coexistence period,"},
#  {'timestamp': (308.76, 314.34),
#   'text': ' then we see that he was able to give his energy in an exciting way as a fox.'},
#  {'timestamp': (314.44, 319.66),
#   'text': " Our dogs don't have that luck in this respect, because we can't always"},
#  {'timestamp': (319.76, 324.66),
#   'text': " use the dog's energy. What happens then? Help me. What happens"},
#  {'timestamp': (324.76, 327.0),
#   'text': " if I can't use the dog's energy? What happens if I can't control the dog's energy?"},
#  {'timestamp': (327.0, 329.0), 'text': ' What happens?'},
#  {'timestamp': (329.0, 332.0), 'text': " And what happens if I'm angry?"},
#  {'timestamp': (332.0, 338.0),
#   'text': " I go home, I open the door and see that he has controlled the dog's energy."},
#  {'timestamp': (338.0, 345.0),
#   'text': " It wasn't funny then, and I laugh at it today. I'm laughing at this, but this is the basis."},
#  {'timestamp': (345.0, 347.0),
#   'text': " And people say, oh, it's so bad, it's so bad."},
#  {'timestamp': (347.0, 351.0),
#   'text': ' Well, please, the fact that the dog is tearing apart the apartment, the dog is tearing apart the apartment,'},
#  {'timestamp': (351.0, 355.0),
#   'text': " it's like, it's going to the dog like the Mercedes to the air conditioner."},
#  {'timestamp': (355.0, 357.0),
#   'text': " I'm asking a Mercedes without air conditioners."},
#  {'timestamp': (357.0, 358.0), 'text': " There's nothing like that."},
#  {'timestamp': (358.0, 360.0),
#   'text': " I'm asking a dog without bad things."},
#  {'timestamp': (360.0, 363.0),
#   'text': ' Let me tell you where you can find a dog like this.'},
#  {'timestamp': (363.0, 364.0), 'text': " I haven't met him yet."},
#  {'timestamp': (364.0, 365.0), 'text': ' Thank God.'},
#  {'timestamp': (365.0, 373.0),
#   'text': " Okay, that's fine. Of course, you can start with this. So there's a chance to treat it, but how?"},
#  {'timestamp': (373.0, 387.0),
#   'text': " Let's look at what's more problematic. When the dog doesn't pick up the apartment, but the energy of the raised bed, this energy that is not led down, where does it appear? Indeed, in behavior disorders, in aggression."},
#  {'timestamp': (387.0, 392.0),
#   'text': ' Most of the behavior problems can be brought back here,'},
#  {'timestamp': (392.0, 394.0),
#   'text': ' the energy that has not been led down.'},
#  {'timestamp': (394.0, 398.0),
#   'text': ' And then there is another one that is even worse than this,'},
#  {'timestamp': (398.0, 403.0),
#   'text': " when this energy overload attacks the body's primary immune system,"},
#  {'timestamp': (403.0, 409.52),
#   'text': ' and the dog becomes much more exposed to diseases.'},
#  {'timestamp': (409.72, 411.8), 'text': ' Dogs are very sick today.'},
#  {'timestamp': (412.0, 417.64),
#   'text': ' So, for those who have had a dog 30-40 years ago, I have similar experts with me,'},
#  {'timestamp': (417.84, 424.6),
#   'text': ' I assume you do, we remember that 30-40 years ago dogs were not so sick.'},
#  {'timestamp': (424.64, 424.84),
#   'text': ' We remember that 30-40 years ago dogs were not so sick.'},
#  {'timestamp': (428.48, 428.68), 'text': ' Our dogs are very sick today.'},
#  {'timestamp': (431.2, 431.4),
#   'text': ' And of course there is nutrition, there is'},
#  {'timestamp': (436.44, 436.64),
#   'text': ' the fact that the air is worse, but these are inferior to what the lifestyle means.'},
#  {'timestamp': (441.36, 441.56),
#   'text': " If I can provide a good lifestyle for the dog, then please, the dog's health"},
#  {'timestamp': (443.44, 443.64),
#   'text': ' status will be drastically improved.'},
#  {'timestamp': (449.68, 454.88),
#   'text': " Well, please, let's see how you can provide a good lifestyle for the dog's health condition will drastically improve. Well, please, let's see how we can provide a good lifestyle for the dog. Let's start with how this happens with the ancestors."},
#  {'timestamp': (454.88, 459.36),
#   'text': " Help me, today you can already know for sure who the dog's ancestor was."},
#  {'timestamp': (459.36, 461.6), 'text': ' The wolf.'},
#  {'timestamp': (461.6, 464.0),
#   'text': ' This is important because when I studied dogology,'},
#  {'timestamp': (464.0, 467.0),
#   'text': " Dr. Zsolt Kovács didn't teach me this yet,"},
#  {'timestamp': (467.0, 472.0),
#   'text': ' but thanks to the recent genetic tests, we now know that the tail is the owner of the dog.'},
#  {'timestamp': (472.0, 476.0),
#   'text': ' Help me! Where does the tail lead its energy?'},
#  {'timestamp': (476.0, 481.0),
#   'text': ' During hunting and playing. Okay. Especially during hunting.'},
#  {'timestamp': (481.0, 487.84),
#   'text': " Let's see how a hunter looks like. The hungry wolves tell the boss that he should slowly start hunting."},
#  {'timestamp': (487.84, 492.84),
#   'text': ' The ladies know this phenomenon well, that how can the hungry wolf be.'},
#  {'timestamp': (492.84, 495.24),
#   'text': " I trust everyone's imagination on what to think."},
#  {'timestamp': (495.24, 496.24), 'text': ' Okay.'},
#  {'timestamp': (496.24, 503.0),
#   'text': ' The boss sees that he has to go, he sends the signal, they start, they see the hunt, they run away.'},
#  {'timestamp': (503.0, 504.0), 'text': ' They destroy.'},
#  {'timestamp': (504.0, 506.0), 'text': ' Is this what a hunting looks like?'},
#  {'timestamp': (506.0, 508.0), 'text': ' Of course not. But how?'},
#  {'timestamp': (508.0, 518.0),
#   'text': " So that these hungry, because this is very important, hungry sheep start hunting with the leader's direction."},
#  {'timestamp': (518.0, 521.0),
#   'text': ' And the leader tells everyone nicely what to do.'},
#  {'timestamp': (521.0, 527.0),
#   'text': ' One of them finds out, the other one is hurrying to out, the third one will be disappointed, the fourth one will decide.'},
#  {'timestamp': (527.0, 547.36),
#   'text': ' The I have two conditions for a good life program. The first is to motivate the dog.'},
#  {'timestamp': (547.36, 550.24),
#   'text': ' What kind of dog does he usually hunt?'},
#  {'timestamp': (550.24, 554.32),
#   'text': ' The hungry dog usually goes hunting.'},
#  {'timestamp': (554.32, 556.32),
#   'text': ' This is the first one to motivate.'},
#  {'timestamp': (556.32, 559.76),
#   'text': ' The second condition is to be guided by the boss.'},
#  {'timestamp': (559.76, 561.76), 'text': ' By the boss.'},
#  {'timestamp': (561.76, 565.0),
#   'text': " Well, let's look at our daily routine."},
#  {'timestamp': (565.0, 570.0),
#   'text': ' A simple dog keeper who puts Border Collie in the car, goes out...'},
#  {'timestamp': (570.0, 577.0),
#   'text': ' What could be the best life mode program for Border Collie? Give me a tip.'},
#  {'timestamp': (579.0, 583.0),
#   'text': " Agility is a great idea, but that's where the winning is."},
#  {'timestamp': (583.0, 586.9),
#   'text': " Agility is a great life mode program, but it's ten times,"},
#  {'timestamp': (587.0, 591.1),
#   'text': ' if not a hundred times stronger than this, because if you see a Border Collie'},
#  {'timestamp': (591.2, 595.1),
#   'text': " bear, you're hungry right away. You can imagine that, right?"},
#  {'timestamp': (595.2, 598.22),
#   'text': ' The bear, the bear, the bear. The Border Collie likes to graze.'},
#  {'timestamp': (598.32, 601.9),
#   'text': " It's hungry in the quoting sign. Okay. The simple dog keeper goes out"},
#  {'timestamp': (602.0, 606.76),
#   'text': ' to the bears, lets the Border Collie out, the Border Collie jumps out, as we have already discussed, and says,'},
#  {'timestamp': (606.76, 609.76),
#   'text': ' Oh, how many dogs! Paf! He runs in and rips them apart.'},
#  {'timestamp': (609.76, 613.24), 'text': " Well, that's not what I thought."},
#  {'timestamp': (613.24, 616.44), 'text': " Let's see how this should work."},
#  {'timestamp': (616.44, 619.24),
#   'text': " Until it's true, oh, how many dogs! Boss, can I go?"},
#  {'timestamp': (619.24, 623.92),
#   'text': ' I say to the boy, okay, boss, you really say, because they are very dogs.'},
#  {'timestamp': (623.92, 629.6),
#   'text': ' And when the boss just comes here once,'},
#  {'timestamp': (629.6, 631.0), 'text': ' he brings the two of us here.'},
#  {'timestamp': (631.0, 633.0),
#   'text': ' Here I am, boss, something else, something else.'},
#  {'timestamp': (633.0, 635.6),
#   'text': ' Well, you know, back to the beginning.'},
#  {'timestamp': (635.6, 637.0),
#   'text': ' Here I am, boss, something else, something else.'},
#  {'timestamp': (637.0, 638.2), 'text': ' This is it.'},
#  {'timestamp': (638.2, 641.2),
#   'text': " This is the lifestyle program we're looking for,"},
#  {'timestamp': (641.2, 644.6),
#   'text': ' high motivation, almost with the control of the owner.'},
#  {'timestamp': (644.6, 649.82),
#   'text': ' And how strong it is, that the little boy is talking here or you...'},
#  {'timestamp': (649.92, 654.86),
#   'text': ' Dear ladies, gentlemen, I have done a lot for the health of my dog,'},
#  {'timestamp': (654.96, 658.78),
#   'text': ' and let me give you a quick example to prove that.'},
#  {'timestamp': (658.88, 662.28),
#   'text': ' A long time ago, a lady came to the Népsziget dog school with'},
#  {'timestamp': (662.38, 669.0),
#   'text': ' a Pista Leslie boxer and told her that the dog has everything to worry about.'},
#  {'timestamp': (669.0, 676.0),
#   'text': " He didn't know how to pet the dog, he had to walk all over the water."},
#  {'timestamp': (676.0, 679.0), 'text': ' This is a strange situation.'},
#  {'timestamp': (679.0, 686.0),
#   'text': " Kriszta's doctors said that the dog has a half year left. And he thought he wanted to beautify this half year,"},
#  {'timestamp': (686.0, 688.0),
#   'text': ' he set the base, then the mid-level training,'},
#  {'timestamp': (688.0, 690.0),
#   'text': ' then he started to go to control training,'},
#  {'timestamp': (690.0, 694.0), 'text': ' one of the forms of defense work.'},
#  {'timestamp': (694.0, 702.0),
#   'text': ' And the defense work of a boxer is like the training of a border collie.'},
#  {'timestamp': (702.0, 708.64),
#   'text': " So if he is not a sympathetic kid, he'll get hungry right away. If I can't get the mayor, I'll say,"},
#  {'timestamp': (708.64, 711.44),
#   'text': " okay, you know what, you're talking. And then you get in the office."},
#  {'timestamp': (711.44, 715.28),
#   'text': " And if he stops, he stops, and if he moves, he'll hold on until he stops."},
#  {'timestamp': (715.28, 719.28),
#   'text': ' That was the Mellow, and imagine, of course, of course, it was completely by accident,'},
#  {'timestamp': (719.28, 726.0),
#   'text': ' it was completely by accident, but what happened was that after Lezli started going to the guard,'},
#  {'timestamp': (726.0, 730.0),
#   'text': ' he started to pee himself from the beginning.'},
#  {'timestamp': (730.0, 732.0), 'text': ' Obviously, it was a coincidence.'},
#  {'timestamp': (732.0, 737.0),
#   'text': ' But when he was on a summer break and he had no business,'},
#  {'timestamp': (737.0, 740.0),
#   'text': " he didn't have a job at the guard, he didn't know how to do it again."},
#  {'timestamp': (740.0, 742.0),
#   'text': ' And again, he got a little bit scared.'},
#  {'timestamp': (742.0, 744.0),
#   'text': ' Krista called the guard teacher Jani,'},
#  {'timestamp': (744.0, 754.0),
#   'text': ' and said, oh, this is it, Jani just for their sake, went to the summer vacation, and to my surprise, the dog could do the job again.'},
#  {'timestamp': (754.0, 766.0),
#   'text': ' But this is not the point of the story, but that on a Budapest big performance, on a November big performance in Budapest three years ago.'},
#  {'timestamp': (766.0, 774.0),
#   'text': ' He said he heard that his dog was taken to the hospital and that he came because Leslie was killed last month.'},
#  {'timestamp': (774.0, 779.0),
#   'text': ' But the dog lived more than 12 years. The dog was almost 13 years old.'},
#  {'timestamp': (779.0, 788.44),
#   'text': ' He was not cured, he was carrying his problems with him, but he was in good condition, in good condition for a long time.'},
#  {'timestamp': (788.44, 791.6),
#   'text': ' So he did a lot to make the dog in good condition.'},
#  {'timestamp': (791.6, 797.88),
#   'text': " Well, please, that's all we've done for the dog, so with high temperature control, with the control of the owner, don't forget that."},
#  {'timestamp': (797.88, 800.16),
#   'text': " There's only one problem with that."},
#  {'timestamp': (800.16, 804.8),
#   'text': " I don't know if you noticed that when my dog is really motivated,"},
#  {'timestamp': (804.8, 808.6),
#   'text': ' so that he really wants to put something on, a cat pops up and he runs in front of it,'},
#  {'timestamp': (808.6, 812.6), 'text': " then it's not that easy to direct."},
#  {'timestamp': (812.6, 816.2), 'text': ' Did you notice? Do you have this?'},
#  {'timestamp': (816.2, 818.2), 'text': ' How not?'},
#  {'timestamp': (818.2, 821.8),
#   'text': ' Yes, because there is, and there is nothing to do about it,'},
#  {'timestamp': (821.8, 826.8),
#   'text': ' there is to make do about it, it is about getting a life-form program that is effective,'},
#  {'timestamp': (826.8, 830.8),
#   'text': " where you first have to get the dog's control."},
#  {'timestamp': (830.8, 834.8),
#   'text': ' This is usually done towards the end of a medium-sized learning process.'},
#  {'timestamp': (834.8, 839.0),
#   'text': " I urge everyone to get this far, but you don't have to hesitate."},
#  {'timestamp': (839.0, 842.3),
#   'text': " I'll give you a tip, just so you understand the philosophy."},
#  {'timestamp': (842.3, 847.6),
#   'text': " I grab the dog's neck, I throw a ball ball, of course, this is a ball dog, if it's not a ball, then something else,"},
#  {'timestamp': (847.6, 866.0),
#   'text': " let's say I fill a dummy with cheese, or I fill a little bag with cheese, but if I pull out a ball, I grab the neck, stay, I push it out, stay, bring it."},
#  {'timestamp': (866.0, 885.6),
#   'text': ' And if you can do this, then you stay a little bigger, one ball, two balls, three balls. Hmmm, bring that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that, that Any dog sport, dog activity can be a very good lifestyle program.'},
#  {'timestamp': (885.6, 887.2), 'text': ' I recommend all of them to you.'},
#  {'timestamp': (887.2, 890.0),
#   'text': " Do the most possible for your dog's health."},
#  {'timestamp': (890.0, 894.4),
#   'text': " I'm going to go and I hope to see you at some of the lifestyle programs."},
#  {'timestamp': (894.4, 899.8),
#   'text': ' Please, now I would like to move on to the teaching, to the second section.'},
#  {'timestamp': (899.8, 903.2),
#   'text': ' We have to look a little bit here to understand the dog.'},
#  {'timestamp': (903.2, 905.76),
#   'text': ' What happens in the case of teaching?'},
#  {'timestamp': (905.76, 912.32),
#   'text': ' Well, please, what happens in the case of teaching, and this is a very interesting situation, is that two beings meet together,'},
#  {'timestamp': (912.32, 916.96),
#   'text': ' and the two beings have a different, the ancient word-love.'},
#  {'timestamp': (916.96, 920.0),
#   'text': ' We talk differently, the human speaks differently, and the dog speaks differently.'},
#  {'timestamp': (920.0, 922.48),
#   'text': ' It is different, our genetic word-love.'},
#  {'timestamp': (922.48, 923.68), 'text': ' Just pay attention.'},
#  {'timestamp': (923.68, 926.0),
#   'text': ' I meet together as a human, Géza, my friend. Hello, Géza, what meet up with my friend Géza as a human being.'},
#  {'timestamp': (926.0, 928.0), 'text': ' Hello, Géza, how are you?'},
#  {'timestamp': (928.0, 930.3),
#   'text': ' I tell him without thinking about it,'},
#  {'timestamp': (930.3, 933.0), 'text': ' selflessly, with a broken arm,'},
#  {'timestamp': (933.0, 934.5),
#   'text': " that I'm getting closer to you with friendship,"},
#  {'timestamp': (934.5, 937.0),
#   'text': " I have no bad intentions, I'm not hiding anything,"},
#  {'timestamp': (937.0, 938.5), 'text': " I don't have a weapon."},
#  {'timestamp': (938.5, 943.0),
#   'text': ' This is what human communication means.'},
#  {'timestamp': (943.0, 944.5),
#   'text': ' Pay attention to the dog, what does it mean?'},
#  {'timestamp': (944.5, 945.0),
#   'text': ' The same sign, pay attention. This is what human communication means. Look at the dog, what does it mean?'},
#  {'timestamp': (945.0, 947.0), 'text': ' The same sign, look at it.'},
#  {'timestamp': (947.0, 952.0),
#   'text': " Look, how big I am, I'm scared of you."},
#  {'timestamp': (952.0, 954.0), 'text': ' Hop!'},
#  {'timestamp': (954.0, 960.0),
#   'text': ' The same sign, it has a completely opposite sign.'},
#  {'timestamp': (960.0, 969.0),
#   'text': ' The dog has no easy job. Pay attention to the typical situation in the park.'},
#  {'timestamp': (969.0, 972.0),
#   'text': ' The puppy barks at the little girl, and she gets scared of the little girl.'},
#  {'timestamp': (972.0, 975.0),
#   'text': " Go away, go away, I'm afraid of you, go away!"},
#  {'timestamp': (975.0, 977.0),
#   'text': ' The little girl is reflecting on this.'},
#  {'timestamp': (977.0, 980.0),
#   'text': " No, little girl, don't be afraid of me, says the little girl."},
#  {'timestamp': (980.0, 982.0), 'text': ' What if the puppy barks?'},
#  {'timestamp': (982.0, 988.0),
#   'text': " You little girl, I'm very sorry, the dog has no easy job."},
#  {'timestamp': (988.0, 996.0),
#   'text': ' But, but, it will soon be clear why we have the dog with us, dear lady, dear sir.'},
#  {'timestamp': (996.0, 1003.0),
#   'text': ' During the evolution of the turtle, different species developed different super abilities,'},
#  {'timestamp': (1003.0, 1007.0),
#   'text': ' which, thanks to them helped them survive the challenges.'},
#  {'timestamp': (1007.0, 1011.0),
#   'text': ' The owl can see well at night, and can hunt in the dark.'},
#  {'timestamp': (1011.0, 1015.0),
#   'text': " The chameleon, if I put it here, it's white and blue,"},
#  {'timestamp': (1015.0, 1017.0),
#   'text': " if I put it there, it's brick-colored."},
#  {'timestamp': (1017.0, 1019.0),
#   'text': ' This is what the chameleon, the mimicry, knows.'},
#  {'timestamp': (1019.0, 1022.0),
#   'text': " What does the dog's ancestor, the wolf, know?"},
#  {'timestamp': (1022.0, 1024.0), 'text': ' What is its super power?'},
#  {'timestamp': (1026.0, 1028.0),
#   'text': ' What does the wolf know about its own super ability? What does the dog know about its own super ability? What does the dog know about its own super ability?'},
#  {'timestamp': (1028.0, 1030.0),
#   'text': ' What does the dog know about its own super ability?'},
#  {'timestamp': (1030.0, 1032.0),
#   'text': ' The smell is very good, but it is not the super ability.'},
#  {'timestamp': (1032.0, 1034.0),
#   'text': ' The smell is very good, but it is not the super ability.'},
#  {'timestamp': (1034.0, 1036.0),
#   'text': ' The smell is very good, but it is not the super ability.'},
#  {'timestamp': (1036.0, 1038.0),
#   'text': ' There is something that is a little different from the smell of animals.'},
#  {'timestamp': (1038.0, 1040.0),
#   'text': ' There is something that is a little different from the smell of animals.'},
#  {'timestamp': (1040.0, 1042.0),
#   'text': ' There is something that knows a little more than other animals.'},
#  {'timestamp': (1042.0, 1044.0),
#   'text': ' Something that knows a little more than other animals.'},
#  {'timestamp': (1044.0, 1048.3),
#   'text': ' Something that knows a little more than other animals. Something that knows a little more than other animals. Please, I just had to say this and they cut it right away.'},
#  {'timestamp': (1048.4, 1052.3),
#   'text': " That's right, social skills, cooperation in the flock."},
#  {'timestamp': (1052.4, 1057.3),
#   'text': ' This is what the wolf knows. A incredibly good communicator.'},
#  {'timestamp': (1057.4, 1061.7),
#   'text': ' You can communicate very well. If you can communicate very well,'},
#  {'timestamp': (1061.8, 1066.0),
#   'text': ' then the dog has inherited this, or inherited it, not just that. hermit, or a hermit, not just any way.'},
#  {'timestamp': (1066.0, 1070.0),
#   'text': ' The dog certainly overcomes the wolf, not even a little bit.'},
#  {'timestamp': (1070.0, 1076.0),
#   'text': ' The dog is already a super social, a super communicative being,'},
#  {'timestamp': (1076.0, 1080.0),
#   'text': " but let's look at the difference between the wolf and the dog."},
#  {'timestamp': (1080.0, 1083.0),
#   'text': ' Who does the wolf usually talk to?'},
#  {'timestamp': (1083.0, 1086.0),
#   'text': ' With the other wolf dog. Who else?'},
#  {'timestamp': (1090.0, 1093.0),
#   'text': ' Well, the one-sided communication with Nyuszi.'},
#  {'timestamp': (1093.0, 1095.0),
#   'text': ' We used to call it non-communication.'},
#  {'timestamp': (1095.0, 1097.0), 'text': " Let's stay with the dog."},
#  {'timestamp': (1097.0, 1099.0), 'text': ' The dog talks to the dog.'},
#  {'timestamp': (1099.0, 1102.0), 'text': ' The dog jumps from here.'},
#  {'timestamp': (1102.0, 1106.0),
#   'text': ' Help me, who does the dog usually talk to?'},
#  {'timestamp': (1106.0, 1110.0), 'text': ' With another dog? With a human?'},
#  {'timestamp': (1110.0, 1118.0),
#   'text': ' With a cat? With a fox? With a horse? With a dog? With a dog?'},
#  {'timestamp': (1118.0, 1126.6),
#   'text': ' Practically all living creatures can be languages in a completely unique way.'},
#  {'timestamp': (1126.6, 1130.4),
#   'text': ' Just think about it, what can I do?'},
#  {'timestamp': (1130.4, 1132.7),
#   'text': ' The dog can raise a Russian and a Tengri.'},
#  {'timestamp': (1132.7, 1133.9), 'text': ' Amazing knowledge.'},
#  {'timestamp': (1133.9, 1135.5), 'text': ' No one else can do it.'},
#  {'timestamp': (1135.5, 1137.6),
#   'text': ' Obviously, life is limited to the limits of life,'},
#  {'timestamp': (1137.6, 1140.8),
#   'text': ' because the golden age and dog friendship are not very much of a story.'},
#  {'timestamp': (1140.8, 1142.9), 'text': ' But, but, but...'},
#  {'timestamp': (1142.9, 1148.0),
#   'text': ' The dog is a communication genius, a language genius.'},
#  {'timestamp': (1148.0, 1152.0),
#   'text': " He doesn't know these languages \u200b\u200bat birth, but he learns them."},
#  {'timestamp': (1152.0, 1156.0),
#   'text': " And that's why the dog is with us, because he is able to learn human language first,"},
#  {'timestamp': (1156.0, 1160.0),
#   'text': ' and he understands that when they say, oh, my little dog, this is how I go home,'},
#  {'timestamp': (1160.0, 1163.0),
#   'text': " they don't say, well, now they're going to get me in the brain."},
#  {'timestamp': (1163.0, 1165.0),
#   'text': ' And when he goes down to the park and talks,'},
#  {'timestamp': (1170.28, 1170.48),
#   'text': ' he says, hey, you, you too, such a guy, what a guy, interesting.'},
#  {'timestamp': (1174.84, 1175.04),
#   'text': ' I think he has such a good head, because the dog has a really good head.'},
#  {'timestamp': (1179.8, 1180.0),
#   'text': ' He is brave enough to say that we talk to him in such a way.'},
#  {'timestamp': (1182.32, 1182.56), 'text': ' Well, please,'},
#  {'timestamp': (1186.56, 1192.08),
#   'text': ' to put this in a little context. It is worth highlighting how I can call the dog.'},
#  {'timestamp': (1192.08, 1194.8),
#   'text': ' I can give information in three ways.'},
#  {'timestamp': (1194.8, 1199.2),
#   'text': ' Help me, what are the three ways I can give information to the dog?'},
#  {'timestamp': (1199.2, 1202.16),
#   'text': ' Is there a body language? What else?'},
#  {'timestamp': (1202.16, 1204.48), 'text': ' My voice is very good.'},
#  {'timestamp': (1204.48, 1208.0),
#   'text': ' And I have facial expressions. These are the three.'},
#  {'timestamp': (1208.0, 1211.0),
#   'text': ' What am I usually most powerful in?'},
#  {'timestamp': (1211.0, 1214.0), 'text': ' Well, in speech, right?'},
#  {'timestamp': (1214.0, 1218.0),
#   'text': ' As you can see, I talk a lot here.'},
#  {'timestamp': (1218.0, 1225.0),
#   'text': " It's very interesting, because for us humans, this is really our main communication area for us humans."},
#  {'timestamp': (1225.0, 1229.0),
#   'text': ' But imagine that in the case of a dog, this is not the case.'},
#  {'timestamp': (1229.0, 1239.0),
#   'text': ' When we pass information to the dog, the information is amazing, but 70% is body language.'},
#  {'timestamp': (1239.0, 1246.0),
#   'text': ' And all in all, only 20% of face is the face.'},
#  {'timestamp': (1246.0, 1250.0),
#   'text': ' And yes, 10% of the voice is left.'},
#  {'timestamp': (1250.0, 1255.0),
#   'text': " That's why it's important to understand and know, because when we talk to the dog,"},
#  {'timestamp': (1255.0, 1260.0),
#   'text': ' when we call the dog, then first of all our body speaks what it speaks to,'},
#  {'timestamp': (1260.0, 1262.0), 'text': ' but we are not conscious of it.'},
#  {'timestamp': (1262.0, 1267.0),
#   'text': " That's why it's hard for us to teach the dog. that's why it's hard to give information to the dog."},
#  {'timestamp': (1267.0, 1288.0),
#   'text': " We used to say that it's a continuous, diagonal, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, knuckle, There are many modern techniques, but dear everyone, the moment has come when we can handle teaching in a decent way."},
#  {'timestamp': (1288.0, 1295.0),
#   'text': ' Practically, the mirror method tells the teacher that no force should be applied to the teacher.'},
#  {'timestamp': (1295.0, 1310.4),
#   'text': ' We invite the dog to a conversation, an interaction, where he also practically takes part as a equal partner in the case of teaching. And we will learn a language for this, and this language is no different than the language of Clicker.'},
#  {'timestamp': (1310.4, 1312.4), 'text': ' This is what we will work with.'},
#  {'timestamp': (1312.4, 1320.2),
#   'text': ' I have worked with many teaching techniques, and I can say with confidence that I consider this the most effective teaching technique.'},
#  {'timestamp': (1320.2, 1325.0),
#   'text': ' It is not by chance that the mirror method is not the only one.'},
#  {'timestamp': (1325.0, 1328.0), 'text': ' What does this clicker mean?'},
#  {'timestamp': (1328.0, 1333.0),
#   'text': ' First of all, you have to understand that this is not a new language,'},
#  {'timestamp': (1333.0, 1335.0),
#   'text': ' neither for the person nor for the dog.'},
#  {'timestamp': (1335.0, 1337.0), 'text': ' We all have to learn this.'},
#  {'timestamp': (1337.0, 1342.0),
#   'text': ' Imagine, I go out into the park and I hear a green dog click.'},
#  {'timestamp': (1342.0, 1345.0),
#   'text': " He says, don't touch me, just tell me."},
#  {'timestamp': (1345.0, 1347.0), 'text': " It's going to bother him enough."},
#  {'timestamp': (1347.0, 1353.0),
#   'text': ' We have to build this clicker, the dog has to learn it, and so do I.'},
#  {'timestamp': (1353.0, 1357.0),
#   'text': ' And this is the key to the success of teaching.'},
#  {'timestamp': (1357.0, 1360.0), 'text': ' We both step towards each other.'},
#  {'timestamp': (1360.0, 1362.0), 'text': ' We both step towards each other.'},
#  {'timestamp': (1362.0, 1364.0),
#   'text': ' This is how learning becomes effective.'},
#  {'timestamp': (1364.0, 1368.0),
#   'text': ' And how does the clicker work? I would like to give you a little help with this now.'},
#  {'timestamp': (1368.0, 1372.0), 'text': ' Dear everyone, this is a camera.'},
#  {'timestamp': (1372.0, 1374.0), 'text': ' This is a camera.'},
#  {'timestamp': (1374.0, 1378.0),
#   'text': " I'm photographing the given moment with it."},
#  {'timestamp': (1378.0, 1381.0), 'text': ' And what does it mean?'},
#  {'timestamp': (1381.0, 1386.6),
#   'text': ' I usually make a photo on every show, and if I could, I would make a group photo now.'},
#  {'timestamp': (1386.6, 1391.2),
#   'text': ' I need your help. I would like to ask you to be kind to everyone to take pictures.'},
#  {'timestamp': (1391.2, 1395.2),
#   'text': " And I'll burn the machine from there, and the picture will be taken in a moment."},
#  {'timestamp': (1395.2, 1398.2),
#   'text': ' I would like to see the photo taken by everyone.'},
#  {'timestamp': (1398.2, 1400.2), 'text': ' From everyone. From everyone.'},
#  {'timestamp': (1400.2, 1410.4),
#   'text': ' Ah, that was a great joy. I did it, sorry, I turned on the smiley sensor. I promise one last thing, no matter what this last one will be, I would like to see the group picture again, the integration.'},
#  {'timestamp': (1410.4, 1417.6),
#   'text': ' Oh, this is true, I already put it in my pocket, in my photo album.'},
#  {'timestamp': (1417.6, 1421.6),
#   'text': ' The dog does exactly the same thing, but where will he store this picture?'},
#  {'timestamp': (1421.6, 1426.0),
#   'text': ' In his mind, he will store it in his mind.'},
#  {'timestamp': (1426.0, 1431.0),
#   'text': " Well, I'm asking you how I can use this every day."},
#  {'timestamp': (1431.0, 1433.0), 'text': ' Just be careful.'},
#  {'timestamp': (1433.0, 1438.0),
#   'text': " What I'm telling you is of course the most basic version of the Click-Buy lesson,"},
#  {'timestamp': (1438.0, 1440.0), 'text': ' but the rest is built on this.'},
#  {'timestamp': (1440.0, 1442.0),
#   'text': ' Because then the starry sky is at the limit.'},
#  {'timestamp': (1442.0, 1444.0), 'text': " Be careful, I'm out in the park."},
#  {'timestamp': (1444.0, 1451.0),
#   'text': " It would be so nice to teach my dog Bobby to sit down, because the neighbor's dog is used to it, but it would be nice for Bobby to run,"},
#  {'timestamp': (1451.0, 1460.0),
#   'text': " Louis Vizsla, when he goes home, Bobby, oh, I'm so bored, there's no one here, oh, there's no one here, he comes to me, you're here, oh, he sits down."},
#  {'timestamp': (1460.0, 1466.0),
#   'text': " And I'm so happy that he sits down that I immediately take a picture of him. And of course I call him to the table, I give him the salad, he eats it."},
#  {'timestamp': (1466.0, 1469.0),
#   'text': ' And what does the simple dog do after that?'},
#  {'timestamp': (1469.0, 1472.0),
#   'text': ' I took a picture, he ate the salad. What does he do after that?'},
#  {'timestamp': (1472.0, 1474.0), 'text': ' What does he do?'},
#  {'timestamp': (1474.0, 1478.0),
#   'text': " He just says what he hasn't heard yet. What does he do?"},
#  {'timestamp': (1478.0, 1481.0), 'text': ' What does he do?'},
#  {'timestamp': (1481.0, 1486.0),
#   'text': " He barks. Well, no one had a simple dog yet. What are you doing? He's going to kill me."},
#  {'timestamp': (1486.0, 1489.0), 'text': ' Nobody had a simple dog yet.'},
#  {'timestamp': (1489.0, 1492.0),
#   'text': ' Everybody was just working with a little thing.'},
#  {'timestamp': (1492.0, 1495.0), 'text': ' He eats the bread and runs away.'},
#  {'timestamp': (1495.0, 1498.0), 'text': ' This is the Mellow.'},
#  {'timestamp': (1498.0, 1500.0),
#   'text': " But there's nothing wrong with that."},
#  {'timestamp': (1500.0, 1505.98),
#   'text': " Next thing, again, Luisi leaves, Bobby, I'm here, here, here, photo, and he's gone, he's gone."},
#  {'timestamp': (1505.98, 1509.78),
#   'text': " I'm like, oh, I used to take photos of him."},
#  {'timestamp': (1509.78, 1512.48),
#   'text': ' Look, you take another photo and sit down and'},
#  {'timestamp': (1512.48, 1517.0),
#   'text': ' how can I not take a photo of him right away?'},
#  {'timestamp': (1517.0, 1521.38),
#   'text': " But now I'm sitting next to him and I'm taking photos like that."},
#  {'timestamp': (1521.38, 1523.34),
#   'text': " I'm sitting and I'm taking photos like that."},
#  {'timestamp': (1523.34, 1529.0),
#   'text': ' Then after a while, I try to tell him the word of the word of the word.'},
#  {'timestamp': (1529.0, 1532.0),
#   'text': " I sit, he doesn't sit down, then I sit down like this."},
#  {'timestamp': (1532.0, 1536.0),
#   'text': ' If he sits down, I take pictures and give the wall to him.'},
#  {'timestamp': (1536.0, 1541.0),
#   'text': ' If he sits down ten times from ten to the word of the word of the word,'},
#  {'timestamp': (1541.0, 1547.0),
#   'text': ' then I have practically taught him the sitting exercise.'},
#  {'timestamp': (1547.0, 1553.0),
#   'text': ' There is only one thing left, what do I think, what can be left?'},
#  {'timestamp': (1553.0, 1555.0), 'text': ' To be ready.'},
#  {'timestamp': (1555.0, 1559.0), 'text': ' I throw away the clicker.'},
#  {'timestamp': (1559.0, 1563.0),
#   'text': ' And this is also an important moment, dear, dear everyone.'},
#  {'timestamp': (1563.0, 1566.0), 'text': ' This is a teaching tool.'},
#  {'timestamp': (1566.0, 1569.0),
#   'text': " That is, not the dog's remote control."},
#  {'timestamp': (1569.0, 1574.0),
#   'text': ' This is for teaching a practice, and then I take it out of it.'},
#  {'timestamp': (1574.0, 1580.0),
#   'text': " Of course, you can repeat it from time to time, you can strengthen it, but I won't do it until the end of my life."},
#  {'timestamp': (1580.0, 1584.0), 'text': " Neighbor, let's move here, okay?"},
#  {'timestamp': (1584.0, 1588.56),
#   'text': " So you don't have to use this until it Bila? So this is not the end of the story, until I teach you."},
#  {'timestamp': (1588.56, 1594.08),
#   'text': ' So in Hungarian, once again, this is a teaching tool, not a dog guide.'},
#  {'timestamp': (1594.08, 1597.92),
#   'text': ' If you experience that somewhere, if you experience that,'},
#  {'timestamp': (1597.92, 1610.2),
#   'text': ' if someone uses the clicker like this, that Buksi, comeucsi, come here, then the lady or the gentleman will be sure that the clicker is not clear.'},
#  {'timestamp': (1610.2, 1613.8),
#   'text': ' Well, please, whoever gets this right, whoever starts on this road,'},
#  {'timestamp': (1613.8, 1620.6),
#   'text': ' can be shot down like a rocket, because we have incredible adventures ahead of us.'},
#  {'timestamp': (1620.6, 1624.0),
#   'text': " I know it's hard, I know you have to be excited at the beginning,"},
#  {'timestamp': (1624.0, 1627.0),
#   'text': " that clicker, my food, it's better, I know you have to taste it at the beginning, that it's spicy, it's a bit too much, it's not tasty, ugh!"},
#  {'timestamp': (1627.0, 1633.0),
#   'text': " At the beginning, it's a bit too much, but it's worth it. I promise."},
#  {'timestamp': (1633.0, 1636.0),
#   'text': " Everyone, don't worry about it, I promise."},
#  {'timestamp': (1636.0, 1658.0),
#   'text': " It's a very effective teaching technique, and it's also good an old school, but it was such a frenetic discovery, catharsis, when we saw and experienced how the click works, so we quickly brought it to Hungary and distributed it, we gave books out, etc."},
#  {'timestamp': (1658.0, 1660.0), 'text': ' We highly recommend it to you.'},
#  {'timestamp': (1660.0, 1662.0), 'text': ' Do it, do it, try it.'},
#  {'timestamp': (1662.0, 1671.0),
#   'text': ' Well, please, this was the lesson. And so towards the end of the lesson, a question, it is very important that some of you have already been on my show,'},
#  {'timestamp': (1671.0, 1687.0),
#   'text': " please help me now not to spoil the questions, let's leave the rhetorical, well, how should I say, a little delicacies in that. I have a question for you."},
#  {'timestamp': (1687.0, 1696.0),
#   'text': ' You have to teach the dog to come here when I tell him to come to me.'},
#  {'timestamp': (1696.0, 1698.0), 'text': " Because he doesn't come here."},
#  {'timestamp': (1698.0, 1701.0),
#   'text': " You've probably seen a dog like this, haven't you?"},
#  {'timestamp': (1701.0, 1705.0),
#   'text': ' You have to teach this dog. I ask for your answer. Now, do you have to teach this dog? Do I ask for an answer?'},
#  {'timestamp': (1705.0, 1708.2), 'text': ' Now, yes or no? Yes or no?'},
#  {'timestamp': (1708.2, 1714.2),
#   'text': " How can I not come here? It's totally logical that I have to teach him, right?"},
#  {'timestamp': (1714.2, 1720.7),
#   'text': " Still, it was true who said that he doesn't have to teach. Smart ass."},
#  {'timestamp': (1720.7, 1723.9), 'text': " He doesn't come here. So what?"},
#  {'timestamp': (1723.9, 1726.0), 'text': " Well, please, this won't be good."},
#  {'timestamp': (1726.0, 1730.0),
#   'text': " I apologize in advance, but why doesn't the next dog come here?"},
#  {'timestamp': (1730.0, 1732.0), 'text': ' In the park.'},
#  {'timestamp': (1732.0, 1734.0), 'text': ' Bobi, come with me!'},
#  {'timestamp': (1734.0, 1737.0),
#   'text': " He looks back, he called me, or he didn't even look back."},
#  {'timestamp': (1737.0, 1742.0),
#   'text': " He sees that the neighbor's a funny guy, he says, look, brother, I can't stand it anymore."},
#  {'timestamp': (1742.0, 1745.0),
#   'text': " Listen, call the guys, I'll tell them to go home, okay?"},
#  {'timestamp': (1745.0, 1750.0),
#   'text': ' He looked at me, called me, saw that I was very, very, very confident,'},
#  {'timestamp': (1750.0, 1755.0),
#   'text': " we're going to be a band at night, but how am I supposed to tell them when we're going home?"},
#  {'timestamp': (1755.0, 1763.0),
#   'text': ' Compared to that, at night, I had my violin in my hand, at 8 p.m., and I said,'},
#  {'timestamp': (1763.0, 1765.0),
#   'text': ' the bell rang, and they were say, Where is the lock?'},
#  {'timestamp': (1765.0, 1767.0), 'text': ' Have you experienced this?'},
#  {'timestamp': (1767.0, 1770.0), 'text': " It's interesting to live at home."},
#  {'timestamp': (1770.0, 1773.0), 'text': ' No? No?'},
#  {'timestamp': (1773.0, 1775.0), 'text': " Then why don't you come in?"},
#  {'timestamp': (1775.0, 1778.0), 'text': " Why don't you come in?"},
#  {'timestamp': (1778.0, 1782.0), 'text': " You're joking. Why?"},
#  {'timestamp': (1782.0, 1785.0),
#   'text': ' Well, please, because I miss the sight.'},
#  {'timestamp': (1785.0, 1787.0), 'text': ' This is the sad situation.'},
#  {'timestamp': (1787.0, 1791.0), 'text': ' This is the sad next question.'},
#  {'timestamp': (1791.0, 1796.0),
#   'text': ' My dog barks with other dogs in my presence.'},
#  {'timestamp': (1796.0, 1799.0), 'text': " You've probably seen this before."},
#  {'timestamp': (1799.0, 1804.0),
#   'text': ' You have to teach them not to bark.'},
#  {'timestamp': (1804.0, 1808.0),
#   'text': " Now I won't be able to beat you again."},
#  {'timestamp': (1808.0, 1812.0),
#   'text': " You don't have to teach them, but smart ass."},
#  {'timestamp': (1812.0, 1816.0), 'text': ' Fighting? Then what?'},
#  {'timestamp': (1816.0, 1819.0),
#   'text': " Well, I'm sorry, I won't like this either. Just watch."},
#  {'timestamp': (1819.0, 1821.0), 'text': ' Dobbelman.'},
#  {'timestamp': (1821.0, 1824.0), 'text': ' A real warrior, strong acerism.'},
#  {'timestamp': (1824.0, 1825.0), 'text': ' Rottweiler, DAAAR!'},
#  {'timestamp': (1825.0, 1833.0),
#   'text': ' The bulldozer, all of them, they leave the home and take their owners for a walk.'},
#  {'timestamp': (1833.0, 1840.0),
#   'text': ' And they go, go, go, and once they meet, they are facing each other.'},
#  {'timestamp': (1840.0, 1866.0),
#   'text': " Then both of them are crushed by the red flag is How many dogs are there? Bobby, let's go over there! For some reason, it doesn't make sense that I..."},
#  {'timestamp': (1866.0, 1868.0), 'text': ' And somehow, why, right?'},
#  {'timestamp': (1868.0, 1870.0), 'text': ' Remember? 70%?'},
#  {'timestamp': (1870.0, 1873.0), 'text': ' What do you say about 90%?'},
#  {'timestamp': (1876.0, 1878.0),
#   'text': " Tuti, I won't be able to stop the conversation?"},
#  {'timestamp': (1878.0, 1880.0), 'text': ' But, simply...'},
#  {'timestamp': (1881.0, 1884.0),
#   'text': " It doesn't make sense that I will stop the conversation."},
#  {'timestamp': (1884.0, 1889.0),
#   'text': ' At this moment, the genetic command is switched on.'},
#  {'timestamp': (1889.0, 1916.0),
# ...
#  {'timestamp': (3824.0, 3828.0),
#   'text': ' I would get such a scolding from the Lord that I would go back quickly.'},
#  {'timestamp': (3828.0, 3837.0),
#   'text': ' In a minute I would have been so angry with the Lord or the lady, because it was an unrespectful self-respect, I ask for your attention.'},
#  {'timestamp': (3837.0, 3848.28),
#   'text': " I couldn't stand it, I entered your private space, I can't do this, I can't step in. This is the private area. Let's see how it actually looks at the Farkas Falka."},
#  {'timestamp': (3848.28, 3851.48),
#   'text': ' How does this private area look like?'},
#  {'timestamp': (3851.48, 3859.88),
#   'text': " He goes hunting, he goes back to the Alfa's private sport, private hunting, and he steps in."},
#  {'timestamp': (3859.88, 3862.28),
#   'text': ' Have you seen this in a natural film, how it looks like?'},
#  {'timestamp': (3862.28, 3868.0),
#   'text': ' He steps in, and as soon as he walks in, he immediately checks the team.'},
#  {'timestamp': (3868.0, 3870.0), 'text': ' Is everything okay with you?'},
#  {'timestamp': (3870.0, 3872.0), 'text': ' Did you eat? Did you eat?'},
#  {'timestamp': (3872.0, 3874.0), 'text': " Don't be silly, is everyone okay?"},
#  {'timestamp': (3874.0, 3876.0),
#   'text': ' He immediately checks the team to see if everything was okay.'},
#  {'timestamp': (3876.0, 3878.0), 'text': ' Do you have it?'},
#  {'timestamp': (3878.0, 3880.0), 'text': ' Do you remember?'},
#  {'timestamp': (3880.0, 3882.0), 'text': ' No?'},
#  {'timestamp': (3882.0, 3884.0), 'text': " Don't you watch natural films?"},
#  {'timestamp': (3884.0, 3885.0),
#   'text': " Do you just watch series? No? Don't they watch nature movies? Just like to watch series of them?"},
#  {'timestamp': (3885.0, 3888.0), 'text': ' No? Of course not!'},
#  {'timestamp': (3888.0, 3889.0), 'text': ' Of course not!'},
#  {'timestamp': (3889.0, 3892.0),
#   'text': ' Well, this is not how it looks at all!'},
#  {'timestamp': (3892.0, 3894.0),
#   'text': ' We are not accidentally getting tired of it.'},
#  {'timestamp': (3894.0, 3895.0), 'text': ' This is how it really looks.'},
#  {'timestamp': (3895.0, 3899.0),
#   'text': ' The alpha walks into the cleaning and the others come forward to greet him.'},
#  {'timestamp': (3899.0, 3901.0),
#   'text': ' Greet him, give him 100 seconds, etc. etc.'},
#  {'timestamp': (3901.0, 3903.0), 'text': ' This alpha kindly...'},
#  {'timestamp': (3903.0, 3908.0),
#   'text': ' ...stops him. He disturbs them, get out of the way, disturb them.'},
#  {'timestamp': (3908.0, 3913.36),
#   'text': ' Then they will be put down, then they will be put down.'},
#  {'timestamp': (3913.36, 3915.6), 'text': ' They will be put down.'},
#  {'timestamp': (3915.6, 3922.0),
#   'text': ' The 25th once just says, you, listen, I want to say that, listen, that,'},
#  {'timestamp': (3922.0, 3930.0),
#   'text': ' what a wonder, there is no need for the 25th to go to the 1st.'},
#  {'timestamp': (3930.0, 3932.0), 'text': ' Max is asking for it.'},
#  {'timestamp': (3932.0, 3934.0), 'text': ' Sir, let me go there.'},
#  {'timestamp': (3934.0, 3936.0),
#   'text': " You don't even want to look at it?"},
#  {'timestamp': (3936.0, 3937.0), 'text': ' Let me go there.'},
#  {'timestamp': (3937.0, 3938.0), 'text': ' Léci, look, how greedy I am.'},
#  {'timestamp': (3938.0, 3939.0), 'text': ' Look.'},
#  {'timestamp': (3939.0, 3941.0), 'text': ' And when can I go in?'},
#  {'timestamp': (3941.0, 3943.0), 'text': ' When can I go in?'},
#  {'timestamp': (3943.0, 3946.0),
#   'text': ' Then, of course. When you get permission. Then you can go in? When you get permission!'},
#  {'timestamp': (3946.0, 3948.0), 'text': ' Exactly!'},
#  {'timestamp': (3948.0, 3950.0), 'text': ' Just like at home.'},
#  {'timestamp': (3950.0, 3952.0), 'text': ' Please pay attention!'},
#  {'timestamp': (3952.0, 3968.0),
#   'text': ' What is coming up now is a good advice.'},
#  {'timestamp': (3968.0, 3972.0),
#   'text': ' I will tell you tips and techniques.'},
#  {'timestamp': (3972.0, 3976.0),
#   'text': " My good news is that you don't have to practice this."},
#  {'timestamp': (3976.0, 3978.0), 'text': ' There is no need for this.'},
#  {'timestamp': (3978.0, 3988.0),
#   'text': ' If your relationship with the dog is fine, then these tricks, these exercises, these domination exercises.'},
#  {'timestamp': (3989.0, 3992.0),
#   'text': ' If you are not in good shape yet, then I recommend you to practice them.'},
#  {'timestamp': (3993.0, 4001.0),
#   'text': ' And to quickly realize whether you need it or not, I will quickly throw you a test that we are doing in our heads right now.'},
#  {'timestamp': (4048.72, 4048.88),
#   'text': " We are almost done, please pay attention, I will tell you the test. If you can call your dog in the park from the playing child, from the ball, from the big dog, from the dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from the big dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, from a dog, through the private area. Let's see. We talked about how the alpha arrives home with the bear."},
#  {'timestamp': (4052.96, 4053.24),
#   'text': ' How do you do a dominance exercise from this when I get home?'},
#  {'timestamp': (4053.52, 4054.44), 'text': ' The...'},
#  {'timestamp': (4055.6, 4056.52), 'text': " There's work..."},
#  {'timestamp': (4059.68, 4059.8),
#   'text': ' The leader, the private sportsman, the work,'},
#  {'timestamp': (4063.16, 4064.88), 'text': ' he comes home at 6 p.m.'},
#  {'timestamp': (4068.0, 4070.0),
#   'text': " I haven't seen him for 10 hours, 9-10 hours, I haven't seen him for 10 hours. I walk in."},
#  {'timestamp': (4072.0, 4074.0), 'text': ' Come here, come here, come here,'},
#  {'timestamp': (4074.0, 4076.0), 'text': ' come here, come here,'},
#  {'timestamp': (4076.0, 4079.0),
#   'text': ' wait a little bit, wait a little bit.'},
#  {'timestamp': (4079.0, 4081.0), 'text': ' Okay.'},
#  {'timestamp': (4081.0, 4087.0),
#   'text': " I'll say it again, if you don't have a problem with the dog, then there's no problem with coming home like this."},
#  {'timestamp': (4087.0, 4105.4),
#   'text': " But if the relationship hasn't really cleared up yet, then the thing that needs to be strengthened is that I come home, It was 6 in the evening, but in the morning..."},
#  {'timestamp': (4106.4, 4109.56), 'text': ' In the morning...'},
#  {'timestamp': (4112.68, 4113.68), 'text': ' I spent an hour and a half...'},
#  {'timestamp': (4114.68, 4122.24), 'text': ' Now!'},
#  {'timestamp': (4123.24, 4124.32), 'text': ' Shut up!'},
#  {'timestamp': (4133.0, 4146.0),
#   'text': " Shut up! And when I see him, I say, what's wrong with you? Why are you acting like this? So he gave up his intention to break into my private space, then I can say, let him go. Let it go! And the puppy is coming! Because the problem is not with the puppy,"},
#  {'timestamp': (4146.0, 4148.0),
#   'text': " it's not with the dog sleeping in the hotel,"},
#  {'timestamp': (4148.0, 4152.0),
#   'text': ' but with the dog not having the control ability.'},
#  {'timestamp': (4152.0, 4156.0),
#   'text': ' So, this would be my first suggestion,'},
#  {'timestamp': (4156.0, 4158.0), 'text': ' and maybe we can practice this...'},
#  {'timestamp': (4158.0, 4160.0), 'text': " I'm going to steal this..."},
#  {'timestamp': (4160.0, 4167.0),
#   'text': ' We have a practice that we usually which we usually give at a basic level of learning,'},
#  {'timestamp': (4167.0, 4179.0),
#   'text': ' that we sit down, I put the chair down on a carpet, I sit down on the chair and I do not let the dog up on the carpet.'},
#  {'timestamp': (4179.0, 4186.0),
#   'text': ' Go down, listen, go down, Gábor, no, do that. Go away. Please, go away.'},
#  {'timestamp': (4186.0, 4188.0), 'text': " Don't you understand?"},
#  {'timestamp': (4188.0, 4192.0), 'text': ' We have to realize this.'},
#  {'timestamp': (4192.0, 4194.0),
#   'text': ' This was the border of private areas.'},
#  {'timestamp': (4194.0, 4196.0), 'text': ' When is there a problem?'},
#  {'timestamp': (4198.0, 4200.0), 'text': " When I can't set it up."},
#  {'timestamp': (4200.0, 4202.0),
#   'text': ' And when there is a very big problem?'},
#  {'timestamp': (4202.0, 4204.0), 'text': ' When he sets it up with me.'},
#  {'timestamp': (4204.0, 4268.0),
#   'text': ' I start work in the morning, I when he gets up in the morning, I go to work at 8 in the morning, Kutus is sleeping, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go, I go tomorrow, oh, oh, oh, what a miracle, what and that, and start collecting the stuff. A torn hi-fi, a torn sofa. Good that Gábor Kámar is here, the stupid dog, three cakes in here.'},
#  {'timestamp': (4268.0, 4277.0),
#   'text': " And when this box is full, let me be careful, then, and it's still wrinkled,"},
#  {'timestamp': (4277.0, 4286.7),
#   'text': " I can't even talk, I sit down on the sofa and wait for the little dog to try to come to me."},
#  {'timestamp': (4286.7, 4290.7),
#   'text': ' And wait! I wait with endless patience,'},
#  {'timestamp': (4290.7, 4294.7),
#   'text': ' that if he comes here, I will put my box of contents on him.'},
#  {'timestamp': (4294.7, 4300.2),
#   'text': ' And when the dog comes, I tell him,'},
#  {'timestamp': (4300.2, 4302.7), 'text': ' get out of here, the dog is here!'},
#  {'timestamp': (4302.7, 4306.0), 'text': ' I put my box on the table.'},
#  {'timestamp': (4306.0, 4310.0),
#   'text': ' Do you remember what happened to the 90%?'},
#  {'timestamp': (4310.0, 4313.0), 'text': ' Did you see that?'},
#  {'timestamp': (4313.0, 4318.0),
#   'text': ' Be careful, this technique is not compatible with when I go home,'},
#  {'timestamp': (4318.0, 4321.0),
#   'text': ' I see that the little dog opened the fridge,'},
#  {'timestamp': (4321.0, 4323.0), 'text': ' and I put the pot here,'},
#  {'timestamp': (4323.0, 4345.1),
#   'text': ' and he still puts it out, Gábor. I put the Get out of here, you idiot! Do you feel the difference? You do?'},
#  {'timestamp': (4346.2, 4346.8), 'text': " Well, that's it."},
#  {'timestamp': (4348.4, 4348.8), 'text': " I'm not kidding, that's it."},
#  {'timestamp': (4349.7, 4350.6), 'text': " It's in one piece."},
#  {'timestamp': (4351.7, 4353.2), 'text': " What you've thought about,"},
#  {'timestamp': (4354.0, 4354.3), 'text': ' you feel it,'},
#  {'timestamp': (4355.6, 4356.7), 'text': ' and you realize it.'},
#  {'timestamp': (4359.6, 4360.1),
#   'text': ' The line of will, will, and will to think is connected.'},
#  {'timestamp': (4361.0, 4361.4), 'text': " It's in one piece."},
#  {'timestamp': (4362.0, 4362.3), 'text': ' Very...'},
#  {'timestamp': (4363.0, 4363.6), 'text': " Well, don't..."},
#  {'timestamp': (4364.1, 4365.2),
#   'text': " Don't... Get lost! It's very rare, but it's the first? Very often. Well, don't... Don't..."},
#  {'timestamp': (4367.2, 4370.2),
#   'text': " ...dissolve yourself! Very rarely, but it's the first time this happens."},
#  {'timestamp': (4370.2, 4371.2), 'text': ' Okay.'},
#  {'timestamp': (4371.2, 4375.2),
#   'text': ' Well, please, this was the border of private space.'},
#  {'timestamp': (4376.2, 4378.2), 'text': " Let's move on to the next one."},
#  {'timestamp': (4378.2, 4379.2), 'text': ' This is no different.'},
#  {'timestamp': (4379.2, 4381.2), 'text': ' This is my thing.'},
#  {'timestamp': (4381.2, 4386.0),
#   'text': " Every living being has a self-sustaining activity, and we don't really like it if others are involved in it."},
#  {'timestamp': (4386.0, 4394.0),
#   'text': ' The more dominant I am, the more I can do my own activity, the less I have to behave to make others get involved in my work.'},
#  {'timestamp': (4394.0, 4399.0),
#   'text': " Let's see how this thing works, the tailed fox."},
#  {'timestamp': (4399.0, 4407.12),
#   'text': " By the way, we are interested in human cohabitation. There are things that the dog can't talk about."},
#  {'timestamp': (4407.12, 4411.36),
#   'text': " You know, there's this engine, this gasoline engine, you know, this damir."},
#  {'timestamp': (4411.36, 4415.6),
#   'text': " And my dog is coming to help me with the hose, I put it like this, the bag is empty, I don't believe it."},
#  {'timestamp': (4415.6, 4421.76),
#   'text': ' We both want to do this alone and not help my dog.'},
#  {'timestamp': (4421.76, 4424.24), 'text': ' We both want this.'},
#  {'timestamp': (4424.24, 4425.0), 'text': ' Okay.'},
#  {'timestamp': (4425.0, 4427.0), 'text': " Let's look at the wolf..."},
#  {'timestamp': (4427.0, 4430.0),
#   'text': " Yes. Let's look at the wolf's tail."},
#  {'timestamp': (4430.0, 4432.0), 'text': ' How do you look at my thing?'},
#  {'timestamp': (4432.0, 4435.0),
#   'text': " What is the most intense activity of the wolf's tail?"},
#  ...]

# %%
def convert_to_srt(result, output_file):
    with open(output_file, 'w', encoding='utf-8') as file:
        for idx, entry in enumerate(result, start=1):
            start_time = "{:02d}:{:02d}:{:06.3f}".format(
                int(entry['timestamp'][0]) // 3600,
                int(entry['timestamp'][0]) % 3600 // 60,
                entry['timestamp'][0] % 60
            )
            end_time = "{:02d}:{:02d}:{:06.3f}".format(
                int(entry['timestamp'][1]) // 3600,
                int(entry['timestamp'][1]) % 3600 // 60,
                entry['timestamp'][1] % 60
            )
            text = entry['text']

            file.write(f"{idx}\n")
            file.write(f"{start_time.replace('.', ',')} --> {end_time.replace('.', ',')}\n")
            file.write(f"{text}\n\n")

# %%
output_file = 'output2.srt'
convert_to_srt(result["chunks"], output_file)
